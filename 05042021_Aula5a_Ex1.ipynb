# %%
#############################################################################################################################################
#############################################################################################################################################
##################################### Autor: Alexandre de Resende Camara ####################################################################
##################################### Data: 05/04/2021 ######################################################################################
##################################### Nome: Aula 5, Exercício 1 #########################################################################
#############################################################################################################################################
# No trinket, faça um programa que cria uma instância de tartaruga do tipo Turtle(definida no módulo turtle do interpretador de Python) e
# imprima na tela o tipo da tartaruga
#
#############################################################################################################################################
# INÍCIO DO CÓDIGO
#############################################################################################################################################
# 
import turtle   
#############################################################################################################################################
leonardo = turtle.Turtle() # Cria uma tartaruga, atribui a leonardo
leonardo.shape("turtle")   # formato de tartaruga.
leonardo.color("blue")

#############################################################################################################################################
type(leonardo)
#############################################################################################################################################
# FIM DO CÓDIGO
# Out:
# turtle.Turtle
