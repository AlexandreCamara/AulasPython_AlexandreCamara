# %%
#####################################################################################################################################################
#####################################################################################################################################################
##################################### Autor: Alexandre de Resende Camara ############################################################################
##################################### Data: 18/05/2021 ##############################################################################################
##################################### Nome: Aula 7-b, Exercício 4 ###################################################################################
#####################################################################################################################################################
# 4) Leia a próxima função e veja se consegue compreender o que ela faz (veja os exemplos no Capítulo 4). Então execute-a e veja se acertou.
#
'''
  t: turtle ou ColabTurtle
  length: comprimento da linha
  n: número de iterações. deve ser maior que zero.
#  '''
############################################################################################################################################
import turtle
############################################################################################################################################
# 
############################################################################################################################################
def draw(t, length, n):
    if n == 0:
        return
    angle = 50
    t.forward(length * n)
    t.left(angle)
    draw(t, length, n-1)
    t.right(2 * angle)
    draw(t, length, n-1)
    t.left(angle)
    t.backward(length * n)
    turtle.exitonclick()
#############################################################################################################################################
joana = turtle.Turtle() # Cria uma tartaruga, atribui a t
joana.shape("turtle")   # formato de tartaruga.
joana.color("black") 
joana.width(3)
joana.speed(2)
t.penup()
joana.goto(-200,-200)
t.pendown()
#############################################################################################################################################
draw(joana,20,20)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-3-becb9a0c6282> in <module>
#      37 joana.goto(-200,-200)
#      38 #############################################################################################################################################
# ---> 39 draw(joana,20,20)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      23     t.forward(length * n)
#      24     t.left(angle)
# ---> 25     draw(t, length, n-1)
#      26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#
# <ipython-input-3-becb9a0c6282> in draw(t, length, n)
#      24     t.left(angle)
#      25     draw(t, length, n-1)
# ---> 26     t.right(2 * angle)
#      27     draw(t, length, n-1)
#      28     t.left(angle)
#
# C:\ProgramData\Anaconda3\lib\turtle.py in right(self, angle)
#    1676         337.0
#    1677         """
# -> 1678         self._rotate(-angle)
#    1679
#    1680     def left(self, angle):
#
# C:\ProgramData\Anaconda3\lib\turtle.py in _rotate(self, angle)
#    3274             for _ in range(steps):
#    3275                 self._orient = self._orient.rotate(delta)
# -> 3276                 self._update()
#    3277         self._orient = neworient
#    3278         self._update()
#
# C:\ProgramData\Anaconda3\lib\turtle.py in _update(self)
#    2658             return
#    2659         elif screen._tracing == 1:
# -> 2660             self._update_data()
#    2661             self._drawturtle()
#    2662             screen._update()                  # TurtleScreenBase
#
# C:\ProgramData\Anaconda3\lib\turtle.py in _update_data(self)
#    2644
#    2645     def _update_data(self):
# -> 2646         self.screen._incrementudc()
#    2647         if self.screen._updatecounter != 0:
#    2648             return
#
# C:\ProgramData\Anaconda3\lib\turtle.py in _incrementudc(self)
#    1290         if not TurtleScreen._RUNNING:
#    1291             TurtleScreen._RUNNING = True
# -> 1292             raise Terminator
#    1293         if self._tracing > 0:
#    1294             self._updatecounter += 1
#
# Terminator:
