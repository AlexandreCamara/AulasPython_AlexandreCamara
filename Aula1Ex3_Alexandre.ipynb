# %%
#################################################################################################################################
#################################################################################################################################
##################################### Autor: Alexandre de Resende Camara ########################################################
##################################### Data: 04/03/2021 ##########################################################################
##################################### Nome: Aula 1, Exercício 3 #################################################################
#################################################################################################################################
# Ache os zeros da função  y = 3 *x^2 - 4 *x -10   
##################################################################################################################################
# Início do código
##################################################################################################################################
# definindo as  constantes a, b e c 
a = 3 
b = -4
c = -10
# Calculando o valor de Delta:
delta = (b ** 2) - (4 * a * c)
##################################################################################################################################
# Cálculo dos zeros da função por Baskara
x_1 = (-b + (delta ** (1/2)))/(2*a)
x_2 = (-b - (delta ** (1/2)))/(2*a)
##################################################################################################################################
# Instruções para o programa:
print("Os zeros da função 'y = 3 *x^2 - 4 *x -10' são:", x_1, "e", x_2)
##################################################################################################################################
# Fim do código
# Out:
# Os zeros da função 'y = 3 *x^2 - 4 *x -10' são: 2.610317298281767 e -1.2769839649484336
