# %%
#####################################################################################################################################################
#####################################################################################################################################################
##################################### Autor: Alexandre de Resende Camara ############################################################################
##################################### Data: 18/05/2021 ##############################################################################################
##################################### Nome: Aula 8, Exercício 2 ###################################################################################
#####################################################################################################################################################
"""Exercício: escreva uma função que receba uma string como argumento e exiba as letras de trás para a frente, uma por linha.
"""
############################################################################################################################################

############################################################################################################################################
# 
############################################################################################################################################
def escada():
    fruta = input("Qual é a fruta desejada?")
    print()
    tamanho = len(fruta)
    for i in range(tamanho):
        letra = fruta[tamanho-1]
        tamanho = tamanho-1
        print(2*i*" " + letra)
        
##########################################################################################################################################
escada()
# Out:
# Qual é a fruta desejada? Laranja
# a
#   j
#     n
#       a
#         r
#           a
#             L
