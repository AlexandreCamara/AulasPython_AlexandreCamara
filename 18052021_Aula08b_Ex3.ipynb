# %%
#####################################################################################################################################################
#####################################################################################################################################################
##################################### Autor: Alexandre de Resende Camara ############################################################################
##################################### Data: 18/05/2021 ##############################################################################################
##################################### Nome: Aula 8b, Exercício 3 ###################################################################################
#####################################################################################################################################################
"""Considere um péndulo simples num plano. O comprimento da linha é $1$ metro, a massa é $0,2 kg$ e a aceleração de gravidade $9,8 m/s^2$. Faça um 
gráfico ou crie uma tabela para a posição em coordenadas cartesianas em função do tempo, utilizando listas.
"""
############################################################################################################################################
from math import *
import matplotlib.pyplot as plt

############################################################################################################################################
# 
############################################################################################################################################
L = 1 # metro
m = 0.2 # kg
g = 9.8 # m/s^2
phi_0 = 0
A = 1 # metro

omega = (g/L)**0.5

tempo = []
for i in range(10):
    t = i
    tempo.append(t)
    
posição=[]

for t in tempo:
    x= A * cos(omega*t+phi_0)
    posição.append(x)

# %%
""" PARTE GRÁFICA"""
plt.plot(tempo,posição)
plt.xlabel("tempo (s)",fontsize=15)
plt.ylabel("posição (m)",fontsize=15)

plt.grid(False)
plt.xlim(0, 10)
plt.ylim()
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rcParams['figure.figsize'] = (15,10)
plt.show()
